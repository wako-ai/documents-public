# %% [markdown]
# # LINE DistilBERT を動かす
#
# - [line-corporation/line-distilbert-base-japanese · Hugging Face](https://huggingface.co/line-corporation/line-distilbert-base-japanese)
# - [高性能・高速・軽量な日本語言語モデル LINE DistilBERTを公開しました](https://engineering.linecorp.com/ja/blog/line-distilbert-high-performance-fast-lightweight-japanese-language-model)

# %%
# Hugging Face transformers をインストール
# !pip install transformers


# 形態素解析器、辞書をインストール
# !pip install fugashi sentencepiece unidic-lite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 87.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.9 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.9/599.9 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658818 sha256=4c8171a17143f95b4065120428fa93ebbeb324173da21ce5d1656ebe56c53433
# ...

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='line-corporation/line-distilbert-base-japanese', trust_remote_code=True)

unmasker("LINE株式会社で[MASK]の研究・開発をしている。")
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/line-corporation/line-distilbert-base-japanese:
# - distilbert_japanese_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertJapaneseTokenizer'.
# The class this function is called from is 'DistilBertJapaneseTokenizer'.
# [{'score': 0.16280142962932587,
#   'token': 2120,
#   'token_str': 'アプリ',
#   'sequence': 'line 株式 会社 で アプリ の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.08094016462564468,
#   'token': 8853,
#   'token_str': 'ai',
#   'sequence': 'line 株式 会社 で ai の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.07631273567676544,
#   'token': 4761,
#   'token_str': 'ソフトウェア',
# ...

# %%
unmasker("理化学研究所で[MASK]の研究・開発をしている。")
# Out:
# [{'score': 0.15745240449905396,
#   'token': 3589,
#   'token_str': '化学',
#   'sequence': '理化学 研究 所 で 化学 の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.12923993170261383,
#   'token': 6050,
#   'token_str': 'ロボット',
#   'sequence': '理化学 研究 所 で ロボット の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.04101453348994255,
#   'token': 2118,
#   'token_str': '科学',
#   'sequence': '理化学 研究 所 で 科学 の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.03333771228790283,
#   'token': 4989,
#   'token_str': '工学',
#   'sequence': '理化学 研究 所 で 工学 の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.03216051682829857,
#   'token': 4264,
#   'token_str': 'コンピュータ',
#   'sequence': '理化学 研究 所 で コンピュータ の 研究 ・ 開発 を し て いる 。'}]

# %%
unmasker("核物理研究センターで[MASK]の研究・開発をしている。")
# Out:
# [{'score': 0.378205269575119,
#   'token': 3790,
#   'token_str': '核',
#   'sequence': '核 物理 研究 センター で 核 の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.08031824231147766,
#   'token': 7522,
#   'token_str': 'ロケット',
#   'sequence': '核 物理 研究 センター で ロケット の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.04252460598945618,
#   'token': 3589,
#   'token_str': '化学',
#   'sequence': '核 物理 研究 センター で 化学 の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.03443511202931404,
#   'token': 6050,
#   'token_str': 'ロボット',
#   'sequence': '核 物理 研究 センター で ロボット の 研究 ・ 開発 を し て いる 。'},
#  {'score': 0.020099006593227386,
#   'token': 2118,
#   'token_str': '科学',
#   'sequence': '核 物理 研究 センター で 科学 の 研究 ・ 開発 を し て いる 。'}]
